# %% [markdown]
# # Attività di progetto 8
# ## Statistica interoperabile
#
# I dati sono arrivati con il file **"ParcoFerrariPM10.json"** .
#
# In questo file, ogni misura raccolta dal sistema di monitoraggio è rappresentata da un **oggetto JSON**:
#
# La statistica che ci è richiesta è la seguente:
# - conteggiare le misure in tre categorie: **BASSO**: particolato da 0 a 10 μg/mc; **MEDIO** tra 10 e 30 μg/mc; **ALTO** oltre 30 μg/mc
# - creare il grafico  a torta basato sui conteggio degli eventi nelle tre categorie
# - la fetta "BASSO" deve essere verde, "MEDIO" deve essere gialla, "ALTO" deve essere rossa.
#
# Anche stavolta, completeremo un programma di cui c'è solo la parte iniziale, quella che legge il file CSV e lo carica nella variabile `archivio_misure`.\

# %%
import json
from matplotlib import pyplot

conta_basso = 0
conta_medio = 0
conta_alto = 0
limite_basso = 10
limite_alto = 30
with open('ParcoFerrariPM10.json', 'r') as f:
    # Continuate il programma da qui...


    # Fin qui
etichette = ['Basso', 'Medio', 'Alto']
colori=['green', 'yellow', 'red']

fig, ax = pyplot.subplots()
ax.pie(fette, labels=etichette, colors=colori, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x4792a38>,
# ...
#  [Text(1.0795966422745695, 0.2108816966677656, 'Basso'),
#   Text(-1.0733760373864378, 0.24054912671757642, 'Medio'),
#   Text(1.007350725186558, -0.44186481695889296, 'Alto')],
#  [Text(0.5888708957861287, 0.1150263800005994, '6.1%'),
#   Text(-0.5854778385744205, 0.13120861457322347, '80.7%'),
#   Text(0.5494640319199406, -0.24101717288666885, '13.2%')])

# %% [markdown]
# ### cosa possiamo fare ?
# Nella cella qui sopra aggiungiamo del codice in questo modo:
#
# 1. Importiamo il sottomodulo pyplot da matplotlib ed il modulo json
# 2. Definiamo tre contatori, uno per categoria, ed i due limiti del basso e dell'alto
# 3. Apriamo il file JSON cn un blocco with e scarichiamo il contenuto in un **array JSON** che corrisponde ad una Lista di Python
# 4. Con un ciclo che legge ciascuna riga della lista :
#    - Se il valore è sotto al limite basso, incremento il contatore del basso
#    - Se il valore è sopra al limite alto, incremento il contatore dell'alto
#    - Altrimenti incremento il contatore del medio
# 6. Usiamo il metodo `pie(lista_valori, labels=lista_etichette, colors=listacolori)` dell'axis per costruire il grafico
